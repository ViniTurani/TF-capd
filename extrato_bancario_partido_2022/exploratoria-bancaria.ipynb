# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
try:
    data = pd.read_csv("extrato_bancario_partido_2022/extrato_bancario_partido_2022.csv", delimiter=';', encoding='latin1')
except UnicodeDecodeError:
    try:
        data = pd.read_csv("extrato_bancario_partido_2022/extrato_bancario_partido_2022.csv", delimiter=';', encoding='iso-8859-1')
    except UnicodeDecodeError:
        data = pd.read_csv("extrato_bancario_partido_2022/extrato_bancario_partido_2022.csv", delimiter=';', encoding='cp1252')

print(data.head())

print(data.info())

print(data.isnull().sum())

for column in data.columns:
    print(data.columns)
# Out:
# /tmp/ipykernel_1079168/2552230834.py:2: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("extrato_bancario_partido_2022/extrato_bancario_partido_2022.csv", delimiter=';', encoding='latin1')
#    DT_GERACAO HH_GERACAO  AA_REFERENCIA  NR_CNPJ_PRESTADOR_CONTA SG_PARTIDO  \
# 0  05/09/2024   00:05:07           2022           15692326000102     AVANTE
# 1  05/09/2024   00:05:07           2022           15692326000102     AVANTE
# 2  05/09/2024   00:05:07           2022           15692326000102     AVANTE
# 3  05/09/2024   00:05:07           2022           15692326000102     AVANTE
# 4  05/09/2024   00:05:07           2022           15692326000102     AVANTE
#
#    NM_ESFERA  TP_PESSOA DS_LANCAMENTO DT_LANCAMENTO NR_DOCUMENTO  ...  \
# 0  Municipal         -1    PAG BOLETO    03/08/2022       425490  ...
# 1  Municipal         -1      PAG AGUA    09/12/2022       460736  ...
# 2  Municipal         -1    DB CEST PJ    13/12/2022       112022  ...
# 3  Municipal          1      CRED TED    13/05/2022           33  ...
# 4  Municipal         -1     SALDO DIA    12/04/2022            0  ...
#
#   VR_LANCAMENTO  CD_BANCO_CONTRAPARTE NM_BANCO_CONTRAPARTE  \
# 0        135,77                    -1               #NULO#
# 1        246,43                    -1               #NULO#
# 2          4,01                    -1               #NULO#
# 3        500,00                    33        BCO SANTANDER
# 4          0,00                    -1               #NULO#
#
#    NR_AGENCIA_CONTRAPARTE  NR_CONTA_CONTRAPARTE  NR_CPF_CNPJ_CONTRAPARTE  \
# 0                      -1                #NULO#                       -1
# 1                      -1                #NULO#                       -1
# 2                      -1                #NULO#           00360305000104
# 3                    3488  00000000000010226176              88168379691
# 4                      -1                #NULO#                       -1
#
#              NM_CONTRAPARTE  CD_FONTE_RECURSO NM_FONTE_RECURSO  \
# 0                    #NULO#            #NULO#           #NULO#
# 1                    #NULO#            #NULO#           #NULO#
# 2   CAIXA ECONOMICA FEDERAL            #NULO#           #NULO#
# 3  CREUZA SILVINA FERNANDES            #NULO#           #NULO#
# 4                    #NULO#            #NULO#           #NULO#
#
#    DS_DETALHE_FONTE_RECURSO
# 0                    #NULO#
# 1                    #NULO#
# 2                    #NULO#
# 3                    #NULO#
# 4                    #NULO#
#
# [5 rows x 28 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909670 entries, 0 to 909669
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DT_GERACAO                909670 non-null  object
#  1   HH_GERACAO                909670 non-null  object
#  2   AA_REFERENCIA             909670 non-null  int64
#  3   NR_CNPJ_PRESTADOR_CONTA   909670 non-null  int64
#  4   SG_PARTIDO                909670 non-null  object
#  5   NM_ESFERA                 909670 non-null  object
#  6   TP_PESSOA                 909670 non-null  int64
#  7   DS_LANCAMENTO             909670 non-null  object
#  8   DT_LANCAMENTO             909670 non-null  object
#  9   NR_DOCUMENTO              909670 non-null  object
#  10  TP_LANCAMENTO             909670 non-null  object
#  11  TP_OPERACAO               909670 non-null  int64
#  12  NM_OPERACAO               909670 non-null  object
#  13  CD_BANCO                  909670 non-null  int64
#  14  NM_BANCO                  909670 non-null  object
#  15  NR_AGENCIA                909670 non-null  int64
#  16  NR_CONTA                  909670 non-null  int64
#  17  TP_CONTA                  909670 non-null  int64
#  18  VR_LANCAMENTO             909670 non-null  object
#  19  CD_BANCO_CONTRAPARTE      909670 non-null  int64
#  20  NM_BANCO_CONTRAPARTE      909670 non-null  object
#  21  NR_AGENCIA_CONTRAPARTE    909670 non-null  int64
#  22  NR_CONTA_CONTRAPARTE      909515 non-null  object
#  23  NR_CPF_CNPJ_CONTRAPARTE   909670 non-null  object
#  24  NM_CONTRAPARTE            909515 non-null  object
#  25  CD_FONTE_RECURSO          909670 non-null  object
#  26  NM_FONTE_RECURSO          909670 non-null  object
#  27  DS_DETALHE_FONTE_RECURSO  909670 non-null  object
# dtypes: int64(10), object(18)
# memory usage: 194.3+ MB
# None
# DT_GERACAO                    0
# HH_GERACAO                    0
# AA_REFERENCIA                 0
# NR_CNPJ_PRESTADOR_CONTA       0
# SG_PARTIDO                    0
# NM_ESFERA                     0
# TP_PESSOA                     0
# DS_LANCAMENTO                 0
# DT_LANCAMENTO                 0
# NR_DOCUMENTO                  0
# TP_LANCAMENTO                 0
# TP_OPERACAO                   0
# NM_OPERACAO                   0
# CD_BANCO                      0
# NM_BANCO                      0
# NR_AGENCIA                    0
# NR_CONTA                      0
# TP_CONTA                      0
# VR_LANCAMENTO                 0
# CD_BANCO_CONTRAPARTE          0
# NM_BANCO_CONTRAPARTE          0
# NR_AGENCIA_CONTRAPARTE        0
# NR_CONTA_CONTRAPARTE        155
# NR_CPF_CNPJ_CONTRAPARTE       0
# NM_CONTRAPARTE              155
# CD_FONTE_RECURSO              0
# NM_FONTE_RECURSO              0
# DS_DETALHE_FONTE_RECURSO      0
# dtype: int64
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')
# Index(['DT_GERACAO', 'HH_GERACAO', 'AA_REFERENCIA', 'NR_CNPJ_PRESTADOR_CONTA',
#        'SG_PARTIDO', 'NM_ESFERA', 'TP_PESSOA', 'DS_LANCAMENTO',
#        'DT_LANCAMENTO', 'NR_DOCUMENTO', 'TP_LANCAMENTO', 'TP_OPERACAO',
#        'NM_OPERACAO', 'CD_BANCO', 'NM_BANCO', 'NR_AGENCIA', 'NR_CONTA',
#        'TP_CONTA', 'VR_LANCAMENTO', 'CD_BANCO_CONTRAPARTE',
#        'NM_BANCO_CONTRAPARTE', 'NR_AGENCIA_CONTRAPARTE',
#        'NR_CONTA_CONTRAPARTE', 'NR_CPF_CNPJ_CONTRAPARTE', 'NM_CONTRAPARTE',
#        'CD_FONTE_RECURSO', 'NM_FONTE_RECURSO', 'DS_DETALHE_FONTE_RECURSO'],
#       dtype='object')

# %%
data['VR_LANCAMENTO'] = data['VR_LANCAMENTO'].astype(str).str.replace(',', '.').astype(float)

# Agrupando os gastos por candidato
gastos_por_candidato = data.groupby(['NR_CPF_CNPJ_CONTRAPARTE', 'SG_PARTIDO'])['VR_LANCAMENTO'].sum()

top_10_gastadores = gastos_por_candidato.nlargest(10).reset_index()

# Plotando o gráfico
plt.figure(figsize=(10, 6))
plt.bar(top_10_gastadores['SG_PARTIDO'], top_10_gastadores['VR_LANCAMENTO'])
plt.title('Distribuição dos Valores Gastos pelos 10 Partidos que Mais Gastaram')
plt.xlabel('Candidato')
plt.ylabel('Valor Gasto (R$)')

plt.xticks(rotation=45)
plt.show()

# %%
estatisticas_por_partido = data.groupby('SG_PARTIDO')['VR_LANCAMENTO'].agg(['mean', 'std','sum'])
print(estatisticas_por_partido)
# Out:
#                        mean           std           sum
# SG_PARTIDO
# #NULO#          1644.216492  4.432918e+04  8.540060e+06
# AGIR           34308.153748  6.418342e+05  1.457410e+08
# AVANTE         44695.393388  9.380082e+05  6.098686e+08
# CIDADANIA      36604.750951  9.694526e+05  6.252458e+08
# DC              9210.012146  1.762980e+05  6.528057e+07
# DEM            12613.788628  5.001152e+05  1.304266e+08
# MDB            32078.100579  2.024273e+06  2.315205e+09
# MOBILIZA       22346.234245  4.730906e+05  8.596596e+07
# NOVO           18694.276267  1.443954e+05  3.222332e+08
# PATRIOTA       42906.110054  1.167938e+06  7.107397e+08
# PC do B        16262.700779  7.245437e+05  4.318235e+08
# PCB             2341.735956  5.839897e+04  7.584883e+06
# PCO            14115.586896  1.409991e+05  7.184834e+06
# PDT            32029.834973  1.437479e+06  1.708792e+09
# PHS              212.905593  5.186064e+03  2.048152e+05
# PL             56182.116231  2.084401e+06  2.024523e+09
# PMB             7611.856862  1.049349e+05  1.770518e+07
# PODE           85356.307899  2.288868e+06  1.987351e+09
# PP             37377.422936  2.037917e+06  2.143072e+09
# PPL                3.187273  2.589353e+01  2.103600e+02
# PROS           51696.756659  1.017672e+06  5.595657e+08
# PRP               18.891051  3.544275e+02  6.649650e+03
# PRTB            3170.960044  4.815482e+04  1.447543e+07
# PSB            25207.900775  1.333931e+06  1.219054e+09
# PSC            25351.107685  8.446788e+05  4.248085e+08
# PSD            50900.257474  2.316323e+06  2.431811e+09
# PSDB           40078.939099  1.709363e+06  2.386380e+09
# PSL            46728.986454  1.233783e+06  3.943926e+08
# PSOL           21896.548869  7.275480e+05  4.430548e+08
# PSTU             434.525246  8.455102e+02  1.428719e+06
# PT              9177.148411  1.297593e+06  1.396615e+09
# PTB            30751.679875  1.033823e+06  7.125472e+08
# PV             12067.251346  3.807333e+05  2.178501e+08
# REDE           49481.212061  1.245240e+06  3.747707e+08
# REPUBLICANOS   32486.952110  1.506619e+06  1.743932e+09
# SDD            29988.844289  8.389086e+05  6.480589e+08
# UNIÃO         194774.522938  6.916812e+06  6.922092e+09
# UP              1722.537755  4.025485e+04  1.144110e+07

# %%
data['VR_LANCAMENTO_NORMALIZADO'] = data.groupby('SG_PARTIDO')['VR_LANCAMENTO'].transform(lambda x: (x - x.mean()) / x.std())
print(data[['SG_PARTIDO', 'VR_LANCAMENTO', 'VR_LANCAMENTO_NORMALIZADO']].head())
# Acho que vamos fazer a normalizacao depois de ter somado os gastos por partido
# Out:
#   SG_PARTIDO  VR_LANCAMENTO  VR_LANCAMENTO_NORMALIZADO
# 0     AVANTE         135.77                  -0.047505
# 1     AVANTE         246.43                  -0.047387
# 2     AVANTE           4.01                  -0.047645
# 3     AVANTE         500.00                  -0.047116
# 4     AVANTE           0.00                  -0.047649

# %%
print("\nVerificação de valores ausentes por coluna:")

missing_values = data.isna().sum()
print(missing_values[missing_values > 0])
# Out:
# Verificação de valores ausentes por coluna:
# NR_CONTA_CONTRAPARTE    155
# NM_CONTRAPARTE          155
# dtype: int64

# %%
columns_to_remove = ["NR_CPF_CNPJ_CONTRAPARTE", "NM_CONTRAPARTE", "CD_FONTE_RECURSO", "NM_FONTE_RECURSO", "DS_DETALHE_FONTE_RECURSO", "CD_BANCO_CONTRAPARTE", "NM_BANCO_CONTRAPARTE", "NR_AGENCIA_CONTRAPARTE", "NR_CONTA_CONTRAPARTE", "NM_ESFERA", "TP_PESSOA", "DS_LANCAMENTO", "DT_LANCAMENTO", "NR_DOCUMENTO", "TP_LANCAMENTO", "TP_OPERACAO", "NM_OPERACAO", "CD_BANCO", "NM_BANCO", "NR_AGENCIA", "NR_CONTA", "TP_CONTA", "DT_GERACAO", "HH_GERACAO", "AA_REFERENCIA", "NR_CNPJ_PRESTADOR_CONTA"]
data_cleaned = data.drop(columns=columns_to_remove)

data_cleaned = data_cleaned.dropna()

data_cleaned.to_csv('data_cleaned_extrato-bancario.csv', index=False)
